# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
filename = '/content/drive/My Drive/UNZIPPED FILE/1.jpg'

# %%
from google.colab import files
file=files.upload()
# Out:
#      <input type="file" id="files-151c833e-3204-413f-a957-6a23c77dddf4" name="files[]" multiple disabled />
#      <output id="result-151c833e-3204-413f-a957-6a23c77dddf4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving haarcascade_frontalface_default.xml to haarcascade_frontalface_default (3).xml

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
face_cascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

img=cv2.imread(filename)
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces=face_cascade.detectMultiScale(img,1.3,5)

print(faces)
# Out:
# [[300  77 159 159]
#  [635  90 160 160]
#  [135 177 151 151]
#  [ 23 353 175 175]
#  [444 374 165 165]
#  [232 409 157 157]
#  [740 432 159 159]]

# %%
for (x,y,w,h) in faces:
  cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
  roi_gray = gray[y:y+h, x:x+w]
  roi_color = img[y:y+h, x:x+w]
plt.grid(None)
plt.xticks([])
plt.yticks([])
imgplot=plt.imshow(img)

# %%
from matplotlib import pyplot

# %%
def draw_faces(filename, result_list):
	
	data = pyplot.imread(filename)
	
	for i in range(len(result_list)):
		
		x1, y1, width, height = result_list[i]
		x2, y2 = x1 + width, y1 + height
		
		pyplot.subplot(1, len(result_list), i+1)
		pyplot.axis('off')
		
		pyplot.imshow(data[y1:y2, x1:x2])
	
	pyplot.show()

# %%
print("Total number of student faces in the classroom  =  ",len(faces))
print("\n\nTweaking the faces of students to give it as output")
draw_faces(filename,faces)
# Out:
# Total number of student faces in the classroom  =   7
#
#
# Tweaking the faces of students to give it as output
